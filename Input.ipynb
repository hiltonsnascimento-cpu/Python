# %% [markdown]
# <a href="https://colab.research.google.com/github/hiltonsnascimento-cpu/Python/blob/main/Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome:")
print("Seu nome é:",nome)
# Out:
# Digite seu nome:Drop sem Where
# Seu nome é:  Drop sem Where

# %% [markdown]
# Atividade 01

# %%
num1 = int(input("Digite seu número:"))
num2 = int(input("Digite seu outro número:"))
soma = num1+num2
print("O resultado será:", soma)
# Out:
# Digite seu número:25
# Digite seu outro número:32
# O resultado será: 57

# %% [markdown]
# Atividade 02

# %%
num1 = int(input("Digite seu número:"))
num2 = int(input("Digite seu outro número:"))
subtracao = num1-num2
print("O resultado será:", subtracao)
# Out:
# Digite seu número:25
# Digite seu outro número:4523
# O resultado será: -4498

# %% [markdown]
# Atividade 03

# %%
num1 = int(input("Digite seu número:"))
num2 = int(input("Digite seu outro número:"))
soma = num1+num2
subtracao = num1-num2
multiplicacao = num1*num2
divisao = num1/num2
print(f"O resultado da soma será: {soma}\nO resultado da subtração será: {subtracao}\nO resultado da multiplicação será: {multiplicacao}\nO resultado da Divisão será: {divisao}")
# Out:
# Digite seu número:456987
# Digite seu outro número:325
# O resultado da soma será: 457312
# O resultado da subtração será: 456662
# O resultado da multiplicação será: 148520775
# O resultado da Divisão será: 1406.1138461538462

# %% [markdown]
# Atividade 04

# %%
nome =input("Digite seu nome: ")
print(f"Olá {nome} Seja bem-Vindo!")
# Out:
# Digite seu nome: Drop Where
# Olá Drop Where Seja bem-Vindo!
